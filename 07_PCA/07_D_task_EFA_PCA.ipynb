# %% [markdown]
# # Principal Component Analysis
#
# ## Task
# In the Portland Housing Prices/Sales Jul 2020 - Jul 2021 dataset, find out whether there is a multicollinearity problem.
#
# - Compute VIF
# - Do EFA
# - Do PCA
# - Optionally L1, L2, Elastic Net
# - Compare the models and select the best one

# %% [markdown]
# # Loading the data

# %%
import pandas as pd

# %%
data = pd.read_csv ("..\\dataset\\portland_filtered.csv",  sep=';')

# %% [markdown]
# # Analysis
# - display the data
# - resolve the NaN values
# - display basic statistics of the data
# - display the correlation matrix

# %% [markdown]
# # Data preparation
# - select the X variables bathrooms', 'bedrooms', 'livingArea','age','price'
# - standardize the variables

# %% [markdown]
# # Display the VIF for each variable

# %% [markdown]
# # EFA
# - Perform EFA
# - Build a model from EFA

# %% [markdown]
# # PCA
# - Perform PCA
# - Build a model from PCA

# %% [markdown]
# # Linear model with L1 and L2
# - Linear model with L1 and L2

# %% [markdown]
# # Model selection
# Which model would you choose and why?
