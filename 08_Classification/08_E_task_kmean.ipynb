# %% [markdown]
# # Customer analysis
#
# We have a list of customers with their personal information and their behavior.
#
# We want to launch a new **luxury and expensive** product on the market.
#
# Which customers should we target with personalized marketing?

# %% [markdown]
# # Task
# - Perform a basic analysis of the data and visualize it
# - Prepare the data (encoding)
# - Select suitable variables by which the customers can be segmented
# - Build a k-means model with a suitable number of segments
# - Visualize the model
# - Which segment is the target one?

# %% [markdown]
# # Loading the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('..\\dataset\\Mall_Customers.csv')

# %% [markdown]
# # Data description
# - Information about the data
# - A preview of the data
# - Basic statistics
# - Displaying the distribution of the data

# %% [markdown]
# # Data preparation
# - Handling NaN values
# - Encoding text columns

# %% [markdown]
# # Variable selection
# - Displaying the relationships between variables (pairplot)
# - Looking for a combination of variables that can be visually split into groups
# - Creating X with only these columns

# %% [markdown]
# # Determining the k-means model parameter
# - Plotting the elbow chart
# - Determining the ideal number of clusters

# %% [markdown]
# # k-means model for the determined number of clusters
# - Training the model
# - Predicting the data

# %% [markdown]
# # Model visualization
# - Plotting the colored groups on charts

# %% [markdown]
# ## Interpreting the model
# - Describe the individual groups
# - Which customers should we target?
