# %% [markdown]
# # Task
#
# Create a convolutional neural network that will process the MNIST dataset.
#
# Compare it to a neural network with fully connected layers.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading and displaying the data

# %%
from keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# Reminder that the values are grayscale shades 0 - 255
# * 0 is black
# * 255 is white

# %%
img = X_train[0]
print (f"min:{np.amin(X_train[0])} max:{np.amax(X_train[0])}")

# %%
def show_images (images, labels, rows=6, cols=10):
    fig, axes = plt.subplots(rows, cols, figsize=(cols, rows))
    for idx in range (0, rows * cols):
        ridx=idx // cols
        cidx=idx % cols
        ax= axes[ridx, cidx]
        ax.axis("off")
        ax.imshow(images[idx], cmap="gray_r")
        ax.set_title(f"{labels[idx]}")
    plt.show()

# %%
show_images(X_train, y_train, 2, 10)

# %% [markdown]
# # Data preparation

# %% [markdown]
# Standardizing values from the range 0 - 255 to the range 0 - 1

# %%
X_train = X_train.astype("float32")/255
X_test = X_test.astype("float32")/255

# %% [markdown]
# Binary encoding

# %%
from keras.utils import to_categorical 
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %% [markdown]
# # Neural network

# %%
import keras
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from keras.models import Sequential

# %%
# Creating and training the model

# %%
model.save('classification_model_mnist')

# %% [markdown]
# # Model training history
# - Show the learning curve
# - Show the model accuracy curve
# - Describe the shapes

# %% [markdown]
# # Model verification
# - Overall model accuracy
# - Accuracy across classes
# - Confusion matrix
# - ROC curves
# - Examples of misclassification

# %% [markdown]
# # Model comparison
# - Which model is more accurate (from the previous chapter or the current one)?
# - What about training time?
# - What about inference time?
