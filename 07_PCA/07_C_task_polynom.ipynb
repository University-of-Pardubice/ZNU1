# %% [markdown]
# # Polynomial regression
#
# ## Task
#
# - Load the dataset with sizes and prices
# - Explore and display the data
# - Build a linear model and find its R²
# - Build polynomial models with various degrees, find their R²
# - Select the best model

# %% [markdown]
# # Loading the data

# %%
import pandas as pd

# %%
data = pd.read_csv ("..\\dataset\\prices.csv",  sep=';')

# %% [markdown]
# # Linear model
# - standardize the data
# - build and train a linear model
# - display the model's parameters
# - visualize the linear model
# - display the model's score

# %% [markdown]
# # Build a polynomial regression model
# - build a 1D polynomial model with degrees 2 - 8
# - display the models
# - display their parameters
# - display their scores
# - Which model would you choose?
